# %% [markdown]
# # Script Mode in SageMaker
# In this page, we will see how to use script mode in SageMaker to submit a training job.
# To do this we will need two files: our training script (present in `pytorch_mnist.py`) and the submission script (this jupyter notebook).
#
# First we need to import the things we will need:
# - `Pytorch`: This is the estimator we will use.
# - `get_execution_role`: We will need this to get the role when initialising our estimator

# %% [markdown]
# ## `pytorch_mnist.py`
# <details>
#   <summary> Click here to see the full script code </summary>
#
# ``` python
# import argparse
# import torch
# import torch.nn as nn
# import torch.nn.functional as F
# import torch.optim as optim
# from torchvision import datasets, transforms
#
# class Net(nn.Module):
#     def __init__(self):
#         super(Net, self).__init__()
#         self.conv1 = nn.Conv2d(1, 32, 3, 1)
#         self.conv2 = nn.Conv2d(32, 64, 3, 1)
#         self.dropout1 = nn.Dropout(0.25)
#         self.dropout2 = nn.Dropout(0.5)
#         self.fc1 = nn.Linear(9216, 128)
#         self.fc2 = nn.Linear(128, 10)
#
#     def forward(self, x):
#         x = self.conv1(x)
#         x = F.relu(x)
#         x = self.conv2(x)
#         x = F.relu(x)
#         x = F.max_pool2d(x, 2)
#         x = self.dropout1(x)
#         x = torch.flatten(x, 1)
#         x = self.fc1(x)
#         x = F.relu(x)
#         x = self.dropout2(x)
#         x = self.fc2(x)
#         output = F.log_softmax(x, dim=1)
#         return output
#
#
# def train(model, train_loader, optimizer, epoch):
#     for batch_idx, (data, target) in enumerate(train_loader):
#         optimizer.zero_grad()
#         output = model(data)
#         loss = F.nll_loss(output, target)
#         loss.backward()
#         optimizer.step()
#         if batch_idx % 100 == 0:
#             print(
#                 "Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}".format(
#                     epoch,
#                     batch_idx * len(data),
#                     len(train_loader.dataset),
#                     100.0 * batch_idx / len(train_loader),
#                     loss.item(),
#                 )
#             )
#
#
# def test(model, test_loader):
#     test_loss = 0
#     correct = 0
#     with torch.no_grad():
#         for data, target in test_loader:
#             output = model(data)
#             test_loss += F.nll_loss(output, target, reduction="sum").item()  # sum up batch loss
#             pred = output.argmax(dim=1, keepdim=True)  # get the index of the max log-probability
#             correct += pred.eq(target.view_as(pred)).sum().item()
#
#     test_loss /= len(test_loader.dataset)
#
#     print(
#         "\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n".format(
#             test_loss, correct, len(test_loader.dataset), 100.0 * correct / len(test_loader.dataset)
#         )
#     )
#
#
# def main():
#     # Training settings
#     parser = argparse.ArgumentParser(description="PyTorch MNIST Example")
#     parser.add_argument(
#         "--batch-size",
#         type=int,
#         default=64,
#         metavar="N",
#         help="input batch size for training (default: 64)",
#     )
#     parser.add_argument(
#         "--test-batch-size",
#         type=int,
#         default=1000,
#         metavar="N",
#         help="input batch size for testing (default: 1000)",
#     )
#     parser.add_argument(
#         "--epochs",
#         type=int,
#         default=14,
#         metavar="N",
#         help="number of epochs to train (default: 14)",
#     )
#     parser.add_argument(
#         "--lr", type=float, default=1.0, metavar="LR", help="learning rate (default: 1.0)"
#     )
#     args = parser.parse_args()
#
#     train_kwargs = {"batch_size": args.batch_size}
#     test_kwargs = {"batch_size": args.test_batch_size}
#
#     transform = transforms.Compose(
#         [transforms.ToTensor(), transforms.Normalize((0.1307,), (0.3081,))]
#     )
#     dataset1 = datasets.MNIST("../data", train=True, download=True, transform=transform)
#     dataset2 = datasets.MNIST("../data", train=False, transform=transform)
#     train_loader = torch.utils.data.DataLoader(dataset1, **train_kwargs)
#     test_loader = torch.utils.data.DataLoader(dataset2, **test_kwargs)
#
#     model = Net()
#
#     optimizer = optim.Adadelta(model.parameters(), lr=args.lr)
#
#     for epoch in range(1, args.epochs + 1):
#         train(model, train_loader, optimizer, epoch)
#         test(model, test_loader)
#
#     torch.save(model.state_dict(), "mnist_cnn.pt")
#
#
# if __name__ == "__main__":
#     main()
# ```
# </details>

# %%
#!pip install sagemaker -U
# Out:
# Collecting sagemaker
#   Downloading sagemaker-2.233.0-py3-none-any.whl.metadata (16 kB)
# Collecting attrs<24,>=23.1.0 (from sagemaker)
#   Downloading attrs-23.2.0-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: boto3<2.0,>=1.34.142 in /Users/soonglee/anaconda3/envs/myenv/lib/python3.8/site-packages (from sagemaker) (1.35.45)
# Collecting cloudpickle==2.2.1 (from sagemaker)
#   Using cached cloudpickle-2.2.1-py3-none-any.whl.metadata (6.9 kB)
# Collecting docker (from sagemaker)
#   Downloading docker-7.1.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting google-pasta (from sagemaker)
#   Using cached google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting importlib-metadata<7.0,>=1.4.0 (from sagemaker)
#   Downloading importlib_metadata-6.11.0-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: jsonschema in /Users/soonglee/anaconda3/envs/myenv/lib/python3.8/site-packages (from sagemaker) (4.23.0)
# Requirement already satisfied: numpy<2.0,>=1.9.0 in /Users/soonglee/anaconda3/envs/myenv/lib/python3.8/site-packages (from sagemaker) (1.24.4)
# Requirement already satisfied: packaging>=20.0 in /Users/soonglee/.local/lib/python3.8/site-packages (from sagemaker) (24.1)
# Requirement already satisfied: pandas in /Users/soonglee/anaconda3/envs/myenv/lib/python3.8/site-packages (from sagemaker) (2.0.3)
# Collecting pathos (from sagemaker)
#   Downloading pathos-0.3.3-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: platformdirs in /Users/soonglee/.local/lib/python3.8/site-packages (from sagemaker) (4.2.2)
# Collecting protobuf<5.0,>=3.12 (from sagemaker)
#   Using cached protobuf-4.25.5-cp37-abi3-macosx_10_9_universal2.whl.metadata (541 bytes)
# Requirement already satisfied: psutil in /Users/soonglee/.local/lib/python3.8/site-packages (from sagemaker) (6.0.0)
# Requirement already satisfied: pyyaml~=6.0 in /Users/soonglee/anaconda3/envs/myenv/lib/python3.8/site-packages (from sagemaker) (6.0.2)
# Requirement already satisfied: requests in /Users/soonglee/anaconda3/envs/myenv/lib/python3.8/site-packages (from sagemaker) (2.32.3)
# Collecting sagemaker-core<2.0.0,>=1.0.0 (from sagemaker)
#   Downloading sagemaker_core-1.0.13-py3-none-any.whl.metadata (4.9 kB)
# Collecting sagemaker-mlflow (from sagemaker)
#   Downloading sagemaker_mlflow-0.1.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting schema (from sagemaker)
#   Downloading schema-0.7.7-py2.py3-none-any.whl.metadata (34 kB)
# Collecting smdebug-rulesconfig==1.0.1 (from sagemaker)
#   Downloading smdebug_rulesconfig-1.0.1-py2.py3-none-any.whl.metadata (943 bytes)
# Collecting tblib<4,>=1.7.0 (from sagemaker)
#   Downloading tblib-3.0.0-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: tqdm in /Users/soonglee/.local/lib/python3.8/site-packages (from sagemaker) (4.66.5)
# Requirement already satisfied: urllib3<3.0.0,>=1.26.8 in /Users/soonglee/anaconda3/envs/myenv/lib/python3.8/site-packages (from sagemaker) (1.26.19)
# Requirement already satisfied: botocore<1.36.0,>=1.35.45 in /Users/soonglee/anaconda3/envs/myenv/lib/python3.8/site-packages (from boto3<2.0,>=1.34.142->sagemaker) (1.35.45)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /Users/soonglee/anaconda3/envs/myenv/lib/python3.8/site-packages (from boto3<2.0,>=1.34.142->sagemaker) (1.0.1)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in /Users/soonglee/anaconda3/envs/myenv/lib/python3.8/site-packages (from boto3<2.0,>=1.34.142->sagemaker) (0.10.3)
# Requirement already satisfied: zipp>=0.5 in /Users/soonglee/anaconda3/envs/myenv/lib/python3.8/site-packages (from importlib-metadata<7.0,>=1.4.0->sagemaker) (3.20.2)
# Collecting pydantic<3.0.0,>=1.7.0 (from sagemaker-core<2.0.0,>=1.0.0->sagemaker)
#   Using cached pydantic-2.9.2-py3-none-any.whl.metadata (149 kB)
# Collecting rich<14.0.0,>=13.0.0 (from sagemaker-core<2.0.0,>=1.0.0->sagemaker)
#   Downloading rich-13.9.4-py3-none-any.whl.metadata (18 kB)
# Collecting mock<5.0,>4.0 (from sagemaker-core<2.0.0,>=1.0.0->sagemaker)
#   Downloading mock-4.0.3-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: importlib-resources>=1.4.0 in /Users/soonglee/anaconda3/envs/myenv/lib/python3.8/site-packages (from jsonschema->sagemaker) (6.4.5)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/soonglee/anaconda3/envs/myenv/lib/python3.8/site-packages (from jsonschema->sagemaker) (2023.12.1)
# Requirement already satisfied: pkgutil-resolve-name>=1.3.10 in /Users/soonglee/anaconda3/envs/myenv/lib/python3.8/site-packages (from jsonschema->sagemaker) (1.3.10)
# Requirement already satisfied: referencing>=0.28.4 in /Users/soonglee/anaconda3/envs/myenv/lib/python3.8/site-packages (from jsonschema->sagemaker) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/soonglee/anaconda3/envs/myenv/lib/python3.8/site-packages (from jsonschema->sagemaker) (0.20.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/soonglee/anaconda3/envs/myenv/lib/python3.8/site-packages (from requests->sagemaker) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/soonglee/anaconda3/envs/myenv/lib/python3.8/site-packages (from requests->sagemaker) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/soonglee/anaconda3/envs/myenv/lib/python3.8/site-packages (from requests->sagemaker) (2024.8.30)
# Requirement already satisfied: six in /Users/soonglee/anaconda3/envs/myenv/lib/python3.8/site-packages (from google-pasta->sagemaker) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/soonglee/.local/lib/python3.8/site-packages (from pandas->sagemaker) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/soonglee/anaconda3/envs/myenv/lib/python3.8/site-packages (from pandas->sagemaker) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in /Users/soonglee/anaconda3/envs/myenv/lib/python3.8/site-packages (from pandas->sagemaker) (2024.2)
# Collecting ppft>=1.7.6.9 (from pathos->sagemaker)
#   Downloading ppft-1.7.6.9-py3-none-any.whl.metadata (12 kB)
# Collecting dill>=0.3.9 (from pathos->sagemaker)
#   Using cached dill-0.3.9-py3-none-any.whl.metadata (10 kB)
# Collecting pox>=0.3.5 (from pathos->sagemaker)
#   Downloading pox-0.3.5-py3-none-any.whl.metadata (8.0 kB)
# Collecting multiprocess>=0.70.17 (from pathos->sagemaker)
#   Downloading multiprocess-0.70.17-py38-none-any.whl.metadata (7.2 kB)
# Collecting mlflow>=2.8 (from sagemaker-mlflow->sagemaker)
#   Downloading mlflow-2.17.2-py3-none-any.whl.metadata (29 kB)
# Collecting mlflow-skinny==2.17.2 (from mlflow>=2.8->sagemaker-mlflow->sagemaker)
#   Downloading mlflow_skinny-2.17.2-py3-none-any.whl.metadata (30 kB)
# Collecting Flask<4 (from mlflow>=2.8->sagemaker-mlflow->sagemaker)
#   Using cached flask-3.0.3-py3-none-any.whl.metadata (3.2 kB)
# Collecting alembic!=1.10.0,<2 (from mlflow>=2.8->sagemaker-mlflow->sagemaker)
#   Downloading alembic-1.14.0-py3-none-any.whl.metadata (7.4 kB)
# Collecting graphene<4 (from mlflow>=2.8->sagemaker-mlflow->sagemaker)
#   Downloading graphene-3.4.1-py2.py3-none-any.whl.metadata (6.9 kB)
# Collecting markdown<4,>=3.3 (from mlflow>=2.8->sagemaker-mlflow->sagemaker)
#   Using cached Markdown-3.7-py3-none-any.whl.metadata (7.0 kB)
# Requirement already satisfied: matplotlib<4 in /Users/soonglee/anaconda3/envs/myenv/lib/python3.8/site-packages (from mlflow>=2.8->sagemaker-mlflow->sagemaker) (3.7.5)
# Collecting pyarrow<18,>=4.0.0 (from mlflow>=2.8->sagemaker-mlflow->sagemaker)
#   Downloading pyarrow-17.0.0-cp38-cp38-macosx_10_15_x86_64.whl.metadata (3.3 kB)
# Requirement already satisfied: scikit-learn<2 in /Users/soonglee/anaconda3/envs/myenv/lib/python3.8/site-packages (from mlflow>=2.8->sagemaker-mlflow->sagemaker) (1.3.2)
# Requirement already satisfied: scipy<2 in /Users/soonglee/anaconda3/envs/myenv/lib/python3.8/site-packages (from mlflow>=2.8->sagemaker-mlflow->sagemaker) (1.10.1)
# Collecting sqlalchemy<3,>=1.4.0 (from mlflow>=2.8->sagemaker-mlflow->sagemaker)
#   Using cached SQLAlchemy-2.0.36-cp38-cp38-macosx_10_9_x86_64.whl.metadata (9.7 kB)
# Requirement already satisfied: Jinja2<4,>=2.11 in /Users/soonglee/anaconda3/envs/myenv/lib/python3.8/site-packages (from mlflow>=2.8->sagemaker-mlflow->sagemaker) (3.1.4)
# Collecting gunicorn<24 (from mlflow>=2.8->sagemaker-mlflow->sagemaker)
#   Downloading gunicorn-23.0.0-py3-none-any.whl.metadata (4.4 kB)
# Collecting cachetools<6,>=5.0.0 (from mlflow-skinny==2.17.2->mlflow>=2.8->sagemaker-mlflow->sagemaker)
#   Using cached cachetools-5.5.0-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: click<9,>=7.0 in /Users/soonglee/.local/lib/python3.8/site-packages (from mlflow-skinny==2.17.2->mlflow>=2.8->sagemaker-mlflow->sagemaker) (8.1.7)
# Collecting databricks-sdk<1,>=0.20.0 (from mlflow-skinny==2.17.2->mlflow>=2.8->sagemaker-mlflow->sagemaker)
#   Downloading databricks_sdk-0.36.0-py3-none-any.whl.metadata (38 kB)
# Collecting gitpython<4,>=3.1.9 (from mlflow-skinny==2.17.2->mlflow>=2.8->sagemaker-mlflow->sagemaker)
#   Downloading GitPython-3.1.43-py3-none-any.whl.metadata (13 kB)
# Collecting opentelemetry-api<3,>=1.9.0 (from mlflow-skinny==2.17.2->mlflow>=2.8->sagemaker-mlflow->sagemaker)
#   Downloading opentelemetry_api-1.28.0-py3-none-any.whl.metadata (1.4 kB)
# Collecting opentelemetry-sdk<3,>=1.9.0 (from mlflow-skinny==2.17.2->mlflow>=2.8->sagemaker-mlflow->sagemaker)
#   Downloading opentelemetry_sdk-1.28.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting sqlparse<1,>=0.4.0 (from mlflow-skinny==2.17.2->mlflow>=2.8->sagemaker-mlflow->sagemaker)
#   Downloading sqlparse-0.5.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting annotated-types>=0.6.0 (from pydantic<3.0.0,>=1.7.0->sagemaker-core<2.0.0,>=1.0.0->sagemaker)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.23.4 (from pydantic<3.0.0,>=1.7.0->sagemaker-core<2.0.0,>=1.0.0->sagemaker)
#   Downloading pydantic_core-2.23.4-cp38-cp38-macosx_10_12_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: typing-extensions>=4.6.1 in /Users/soonglee/anaconda3/envs/myenv/lib/python3.8/site-packages (from pydantic<3.0.0,>=1.7.0->sagemaker-core<2.0.0,>=1.0.0->sagemaker) (4.12.2)
# Collecting markdown-it-py>=2.2.0 (from rich<14.0.0,>=13.0.0->sagemaker-core<2.0.0,>=1.0.0->sagemaker)
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/soonglee/.local/lib/python3.8/site-packages (from rich<14.0.0,>=13.0.0->sagemaker-core<2.0.0,>=1.0.0->sagemaker) (2.18.0)
# Collecting Mako (from alembic!=1.10.0,<2->mlflow>=2.8->sagemaker-mlflow->sagemaker)
#   Downloading Mako-1.3.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting Werkzeug>=3.0.0 (from Flask<4->mlflow>=2.8->sagemaker-mlflow->sagemaker)
#   Using cached werkzeug-3.0.6-py3-none-any.whl.metadata (3.7 kB)
# Collecting itsdangerous>=2.1.2 (from Flask<4->mlflow>=2.8->sagemaker-mlflow->sagemaker)
#   Downloading itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting blinker>=1.6.2 (from Flask<4->mlflow>=2.8->sagemaker-mlflow->sagemaker)
#   Using cached blinker-1.8.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting graphql-core<3.3,>=3.1 (from graphene<4->mlflow>=2.8->sagemaker-mlflow->sagemaker)
#   Downloading graphql_core-3.2.5-py3-none-any.whl.metadata (10 kB)
# Collecting graphql-relay<3.3,>=3.1 (from graphene<4->mlflow>=2.8->sagemaker-mlflow->sagemaker)
#   Downloading graphql_relay-3.2.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/soonglee/anaconda3/envs/myenv/lib/python3.8/site-packages (from Jinja2<4,>=2.11->mlflow>=2.8->sagemaker-mlflow->sagemaker) (2.1.5)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich<14.0.0,>=13.0.0->sagemaker-core<2.0.0,>=1.0.0->sagemaker)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/soonglee/anaconda3/envs/myenv/lib/python3.8/site-packages (from matplotlib<4->mlflow>=2.8->sagemaker-mlflow->sagemaker) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /Users/soonglee/anaconda3/envs/myenv/lib/python3.8/site-packages (from matplotlib<4->mlflow>=2.8->sagemaker-mlflow->sagemaker) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/soonglee/anaconda3/envs/myenv/lib/python3.8/site-packages (from matplotlib<4->mlflow>=2.8->sagemaker-mlflow->sagemaker) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/soonglee/anaconda3/envs/myenv/lib/python3.8/site-packages (from matplotlib<4->mlflow>=2.8->sagemaker-mlflow->sagemaker) (1.4.7)
# Requirement already satisfied: pillow>=6.2.0 in /Users/soonglee/anaconda3/envs/myenv/lib/python3.8/site-packages (from matplotlib<4->mlflow>=2.8->sagemaker-mlflow->sagemaker) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/soonglee/anaconda3/envs/myenv/lib/python3.8/site-packages (from matplotlib<4->mlflow>=2.8->sagemaker-mlflow->sagemaker) (3.1.4)
# Requirement already satisfied: joblib>=1.1.1 in /Users/soonglee/anaconda3/envs/myenv/lib/python3.8/site-packages (from scikit-learn<2->mlflow>=2.8->sagemaker-mlflow->sagemaker) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/soonglee/anaconda3/envs/myenv/lib/python3.8/site-packages (from scikit-learn<2->mlflow>=2.8->sagemaker-mlflow->sagemaker) (3.5.0)
# Collecting greenlet!=0.4.17 (from sqlalchemy<3,>=1.4.0->mlflow>=2.8->sagemaker-mlflow->sagemaker)
#   Downloading greenlet-3.1.1-cp38-cp38-macosx_11_0_universal2.whl.metadata (3.8 kB)
# Collecting google-auth~=2.0 (from databricks-sdk<1,>=0.20.0->mlflow-skinny==2.17.2->mlflow>=2.8->sagemaker-mlflow->sagemaker)
#   Downloading google_auth-2.36.0-py2.py3-none-any.whl.metadata (4.7 kB)
# Collecting gitdb<5,>=4.0.1 (from gitpython<4,>=3.1.9->mlflow-skinny==2.17.2->mlflow>=2.8->sagemaker-mlflow->sagemaker)
#   Downloading gitdb-4.0.11-py3-none-any.whl.metadata (1.2 kB)
# Collecting deprecated>=1.2.6 (from opentelemetry-api<3,>=1.9.0->mlflow-skinny==2.17.2->mlflow>=2.8->sagemaker-mlflow->sagemaker)
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl.metadata (5.4 kB)
# Collecting opentelemetry-semantic-conventions==0.49b0 (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==2.17.2->mlflow>=2.8->sagemaker-mlflow->sagemaker)
#   Downloading opentelemetry_semantic_conventions-0.49b0-py3-none-any.whl.metadata (2.4 kB)
# Collecting wrapt<2,>=1.10 (from deprecated>=1.2.6->opentelemetry-api<3,>=1.9.0->mlflow-skinny==2.17.2->mlflow>=2.8->sagemaker-mlflow->sagemaker)
#   Using cached wrapt-1.16.0-cp38-cp38-macosx_10_9_x86_64.whl.metadata (6.6 kB)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==2.17.2->mlflow>=2.8->sagemaker-mlflow->sagemaker)
#   Downloading smmap-5.0.1-py3-none-any.whl.metadata (4.3 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.17.2->mlflow>=2.8->sagemaker-mlflow->sagemaker)
#   Using cached pyasn1_modules-0.4.1-py3-none-any.whl.metadata (3.5 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.17.2->mlflow>=2.8->sagemaker-mlflow->sagemaker)
#   Using cached rsa-4.9-py3-none-any.whl.metadata (4.2 kB)
# Collecting pyasn1<0.7.0,>=0.4.6 (from pyasn1-modules>=0.2.1->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.17.2->mlflow>=2.8->sagemaker-mlflow->sagemaker)
#   Using cached pyasn1-0.6.1-py3-none-any.whl.metadata (8.4 kB)
# Downloading sagemaker-2.233.0-py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 4.3 MB/s eta 0:00:00a 0:00:01
# Downloading cloudpickle-2.2.1-py3-none-any.whl (25 kB)
# Downloading smdebug_rulesconfig-1.0.1-py2.py3-none-any.whl (20 kB)
# Downloading attrs-23.2.0-py3-none-any.whl (60 kB)
# Downloading importlib_metadata-6.11.0-py3-none-any.whl (23 kB)
# Using cached protobuf-4.25.5-cp37-abi3-macosx_10_9_universal2.whl (394 kB)
# Downloading sagemaker_core-1.0.13-py3-none-any.whl (389 kB)
# Downloading tblib-3.0.0-py3-none-any.whl (12 kB)
# Downloading docker-7.1.0-py3-none-any.whl (147 kB)
# Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Downloading pathos-0.3.3-py3-none-any.whl (82 kB)
# Downloading sagemaker_mlflow-0.1.0-py3-none-any.whl (24 kB)
# Downloading schema-0.7.7-py2.py3-none-any.whl (18 kB)
# Downloading dill-0.3.9-py3-none-any.whl (119 kB)
# Downloading mlflow-2.17.2-py3-none-any.whl (26.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.7/26.7 MB 3.5 MB/s eta 0:00:0000:0100:01
# Downloading mlflow_skinny-2.17.2-py3-none-any.whl (5.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 3.6 MB/s eta 0:00:00a 0:00:01
# Downloading mock-4.0.3-py3-none-any.whl (28 kB)
# Downloading multiprocess-0.70.17-py38-none-any.whl (132 kB)
# Downloading pox-0.3.5-py3-none-any.whl (29 kB)
# Downloading ppft-1.7.6.9-py3-none-any.whl (56 kB)
# Downloading pydantic-2.9.2-py3-none-any.whl (434 kB)
# Downloading pydantic_core-2.23.4-cp38-cp38-macosx_10_12_x86_64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 3.6 MB/s eta 0:00:00a 0:00:01
# Downloading rich-13.9.4-py3-none-any.whl (242 kB)
# Downloading alembic-1.14.0-py3-none-any.whl (233 kB)
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading flask-3.0.3-py3-none-any.whl (101 kB)
# Downloading graphene-3.4.1-py2.py3-none-any.whl (114 kB)
# Downloading gunicorn-23.0.0-py3-none-any.whl (85 kB)
# Using cached Markdown-3.7-py3-none-any.whl (106 kB)
# Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Downloading pyarrow-17.0.0-cp38-cp38-macosx_10_15_x86_64.whl (29.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.0/29.0 MB 3.7 MB/s eta 0:00:0000:0100:01
# Downloading SQLAlchemy-2.0.36-cp38-cp38-macosx_10_9_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 3.6 MB/s eta 0:00:00a 0:00:01
# Downloading blinker-1.8.2-py3-none-any.whl (9.5 kB)
# Using cached cachetools-5.5.0-py3-none-any.whl (9.5 kB)
# Downloading databricks_sdk-0.36.0-py3-none-any.whl (569 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 569.1/569.1 kB 3.0 MB/s eta 0:00:00
# Downloading GitPython-3.1.43-py3-none-any.whl (207 kB)
# Downloading graphql_core-3.2.5-py3-none-any.whl (203 kB)
# Downloading graphql_relay-3.2.0-py3-none-any.whl (16 kB)
# Downloading greenlet-3.1.1-cp38-cp38-macosx_11_0_universal2.whl (271 kB)
# Downloading itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Downloading opentelemetry_api-1.28.0-py3-none-any.whl (64 kB)
# Downloading opentelemetry_sdk-1.28.0-py3-none-any.whl (118 kB)
# Downloading opentelemetry_semantic_conventions-0.49b0-py3-none-any.whl (159 kB)
# Downloading sqlparse-0.5.1-py3-none-any.whl (44 kB)
# Downloading werkzeug-3.0.6-py3-none-any.whl (227 kB)
# Downloading Mako-1.3.6-py3-none-any.whl (78 kB)
# Downloading Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
# Downloading google_auth-2.36.0-py2.py3-none-any.whl (209 kB)
# Using cached pyasn1_modules-0.4.1-py3-none-any.whl (181 kB)
# Using cached rsa-4.9-py3-none-any.whl (34 kB)
# Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Using cached wrapt-1.16.0-cp38-cp38-macosx_10_9_x86_64.whl (37 kB)
# Using cached pyasn1-0.6.1-py3-none-any.whl (83 kB)
# Installing collected packages: schema, wrapt, Werkzeug, tblib, sqlparse, smmap, smdebug-rulesconfig, pydantic-core, pyasn1, pyarrow, protobuf, ppft, pox, mock, mdurl, Mako, itsdangerous, importlib-metadata, gunicorn, greenlet, graphql-core, google-pasta, dill, cloudpickle, cachetools, blinker, attrs, annotated-types, sqlalchemy, rsa, pydantic, pyasn1-modules, multiprocess, markdown-it-py, markdown, graphql-relay, gitdb, Flask, docker, deprecated, rich, pathos, opentelemetry-api, graphene, google-auth, gitpython, alembic, opentelemetry-semantic-conventions, databricks-sdk, sagemaker-core, opentelemetry-sdk, mlflow-skinny, mlflow, sagemaker-mlflow, sagemaker
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib_metadata 8.5.0
#     Uninstalling importlib_metadata-8.5.0:
#       Successfully uninstalled importlib_metadata-8.5.0
#   Attempting uninstall: attrs
#     Found existing installation: attrs 24.2.0
#     Uninstalling attrs-24.2.0:
#       Successfully uninstalled attrs-24.2.0
# Successfully installed Flask-3.0.3 Mako-1.3.6 Werkzeug-3.0.6 alembic-1.14.0 annotated-types-0.7.0 attrs-23.2.0 blinker-1.8.2 cachetools-5.5.0 cloudpickle-2.2.1 databricks-sdk-0.36.0 deprecated-1.2.14 dill-0.3.9 docker-7.1.0 gitdb-4.0.11 gitpython-3.1.43 google-auth-2.36.0 google-pasta-0.2.0 graphene-3.4.1 graphql-core-3.2.5 graphql-relay-3.2.0 greenlet-3.1.1 gunicorn-23.0.0 importlib-metadata-6.11.0 itsdangerous-2.2.0 markdown-3.7 markdown-it-py-3.0.0 mdurl-0.1.2 mlflow-2.17.2 mlflow-skinny-2.17.2 mock-4.0.3 multiprocess-0.70.17 opentelemetry-api-1.28.0 opentelemetry-sdk-1.28.0 opentelemetry-semantic-conventions-0.49b0 pathos-0.3.3 pox-0.3.5 ppft-1.7.6.9 protobuf-4.25.5 pyarrow-17.0.0 pyasn1-0.6.1 pyasn1-modules-0.4.1 pydantic-2.9.2 pydantic-core-2.23.4 rich-13.9.4 rsa-4.9 sagemaker-2.233.0 sagemaker-core-1.0.13 sagemaker-mlflow-0.1.0 schema-0.7.7 smdebug-rulesconfig-1.0.1 smmap-5.0.1 sqlalchemy-2.0.36 sqlparse-0.5.1 tblib-3.0.0 wrapt-1.16.0

# %%
from sagemaker.pytorch import PyTorch
from sagemaker import get_execution_role
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from sagemaker.pytorch import PyTorch
#       2 from sagemaker import get_execution_role
#
# ModuleNotFoundError: No module named 'sagemaker'

# %% [markdown]
# Next we will create a dictionary containing our hyperparameters. These hyperparameters need to be taken as command-line arguments in your training script.

# %%
hyperparameters = {"epochs": "2", "batch-size": "32", "test-batch-size": "100", "lr": "0.001"}

# %% [markdown]
# Next we will initialise our estimator. Here we need to specify the:
# - `entry_point`: The path of the training script
# - `base_job_name`: The name of the job
# - `instance_type`: The type of training instance you want to use
# - `instance_count`: The number of training instances to use
# - `framework_version`: The version of pytorch you want in your training instance
# - `py_version`: The version of Python you want in your training instance

# %%
estimator = PyTorch(
    entry_point="pytorch_mnist.py",
    base_job_name="sagemaker-script-mode",
    role=get_execution_role(),
    instance_count=1,
    instance_type="ml.m5.large",
    hyperparameters=hyperparameters,
    framework_version="1.8",
    py_version="py36",
)

# %% [markdown]
# Calling the `fit()` method will start training. By setting `wait=True`, this line will be blocking, meaning that the rest of the code will not run until the training job finishes.

# %%
estimator.fit(wait=True)

# %% [markdown]
# Next you can see some of the details of the training like the job name, the hyperparameters used for training and the location where the trained model is saved.

# %%
estimator.base_job_name

# %%
estimator.hyperparameters()

# %%
estimator.model_data
